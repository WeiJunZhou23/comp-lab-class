# %%
import numpy as np
import matplotlib.pyplot as plt
import mdtraj as md
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('ala2_metad_biasfactor10_pace500_height1.2_sigma0.3_10ns_2d_fes.dat', sep='\s+', skiprows=9, header=None)
df.columns = ['phi', 'psi', 'free ene', 'der_phi', 'der_psi']
df
# Out:
#            phi       psi   free ene    der_phi    der_psi
# 0    -3.141593 -3.141593 -77.895469 -48.774350  17.452657
# 1    -3.043418 -3.141593 -82.254681 -39.911322  17.395098
# 2    -2.945243 -3.141593 -85.707354 -30.396884  17.183013
# 3    -2.847068 -3.141593 -88.217539 -20.768174  16.971645
# 4    -2.748894 -3.141593 -89.798367 -11.564459  16.894238
# ...        ...       ...        ...        ...        ...
# 2235  2.650719  2.962073 -49.273639 -63.911793   3.328060
# 2236  2.748894  2.962073 -55.778276 -67.906115   4.224492
# 2237  2.847068  2.962073 -62.464394 -67.687555   5.276065
# 2238  2.945243  2.962073 -68.947177 -63.866783   6.267805
# 2239  3.043418  2.962073 -74.916608 -57.364306   7.022196
#
# [2240 rows x 5 columns]

# %%
data = df['free ene'].to_numpy(dtype='float')
data
# Out:
# array([-77.89546894, -82.25468134, -85.70735388, ..., -62.46439439,
#        -68.94717715, -74.91660779])

# %%
H, xedges, yedges = np.histogram2d(df['phi'].to_numpy(), df['psi'].to_numpy(), bins=50)
H = - np.log(H.T)
H = H - np.min(H)
extent = (np.min(df['phi']), np.max(df['phi']), np.min(df['psi']), np.max(df['psi']))
plt.figure(figsize=(6, 6))
ax.set_facecolor('blue')
plt.imshow(H, interpolation='nearest', origin='lower', extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]], aspect='auto')
plt.xlabel('Phi')
plt.ylabel('Psi')
# plt.ylim(-5, 5)
# plt.xlim(-3, 3)
plt.title("Free Energy Surface 300K_replica", fontsize=15)
plt.colorbar()
#plt.savefig("Free_ene_surface_300K.png", dpi=500, bbox_inches='tight')
plt.show()
# Out:
# /state/partition1/job-26418360/ipykernel_2998552/3164139056.py:2: RuntimeWarning: divide by zero encountered in log
#   H = - np.log(H.T)

# %%
plt.figure()
plt.imshow(data, interpolation="nearest", cmap="RdYlGn_r", aspect='auto')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 plt.figure()
# ----> 2 plt.imshow(data, interpolation="nearest", cmap="RdYlGn_r", aspect='auto')
#       3 plt.show()
#
# File /ext3/miniconda3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py:459, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     453 if len(args) > name_idx:
#     454     warn_deprecated(
#     455         since, message="Passing the %(name)s %(obj_type)s "
#     456         "positionally is deprecated since Matplotlib %(since)s; the "
#     457         "parameter will become keyword-only %(removal)s.",
#     458         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459 return func(*args, **kwargs)
#
# ...
