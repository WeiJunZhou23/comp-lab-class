# %%
import pandas as pd
from matplotlib import pyplot as plt
import mdtraj as md
import numpy as np

# %%
df = pd.read_csv('meta_biasfactor10_pace500_height1.2_sigma0.28_10ns_fes.dat', sep='\s+', skiprows=5, header=None)
df.columns=['phi','free_ene','der_phi']
df.head(10)
# Out:
#         phi    free_ene    der_phi
# 0 -3.141593 -103.070277 -48.969772
# 1 -3.043418 -107.497150 -41.154478
# 2 -2.945243 -111.130662 -32.804063
# 3 -2.847068 -113.920630 -23.983238
# 4 -2.748894 -115.833945 -15.081417
# 5 -2.650719 -116.894954  -6.760386
# 6 -2.552544 -117.205947   0.059736
# 7 -2.454369 -116.949186   4.659119
# 8 -2.356194 -116.357347   6.946304
# 9 -2.258020 -115.639624   7.299228

# %%
plt.figure()
plt.plot(df['phi'], df['free_ene'])
plt.xlabel('Φ / radians')
plt.ylabel('Free energy / kJ mol^-1')
plt.title('Free energy V.S. dihedral phi from a 10ns metadynamics simulation')
plt.savefig('part_3_negative_energy_column_grid_file.png')
plt.show()
