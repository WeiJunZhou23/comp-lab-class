# %%
import pandas as pd
from matplotlib import pyplot as plt
import mdtraj as md
import numpy as np

# %%
df = pd.read_csv('part_3_add_METAD_PACE500_HEIGHT1.2_BIASFACTOR10_SIGMA0.28_GRID_WSTRIDE10000.grid.dat', sep='\s+', skiprows=5, header=None)
df.columns = ['phi', 'meted.bias', 'der_phi']
df
# Out:
#           phi  meted.bias    der_phi
# 0   -3.141593   92.732988  43.833364
# 1   -3.085989   95.078578  39.988000
# 2   -3.030386   97.200696  35.912724
# 3   -2.974782   99.088974  31.637728
# 4   -2.919179  100.736696  27.277092
# ..        ...         ...        ...
# 108  2.863576   78.151146  58.970467
# 109  2.919179   81.384748  56.879875
# 110  2.974782   84.487946  54.274833
# 111  3.030386   87.429249  51.115148
# 112  3.085989   90.183107  47.635024
#
# [113 rows x 3 columns]

# %%
plt.figure()
plt.plot(-df['meted.bias'])
plt.title('Energy')
plt.ylabel('Energy kJ/mol')
plt.savefig('part3_additional_grid_Energy.png', dpi=500, bbox_inches='tight')
plt.show()
