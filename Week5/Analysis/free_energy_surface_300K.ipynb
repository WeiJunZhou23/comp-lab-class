# %%
import numpy as np
import matplotlib.pyplot as plt
import mdtraj as md
import numpy as np

# %%
traj = md.load_trr('adp_exchange4temps.trr', top = 'adp_exchange4temps.gro')

# %%
phi_angles = md.compute_phi(traj)
psi_angles = md.compute_psi(traj)

# %%
H, xedges, yedges = np.histogram2d(phi_angles[1].flatten(), psi_angles[1].flatten(), bins=50)
H = - np.log(H.T)
H = H - np.min(H)
plt.figure(figsize=(6, 6))
ax=plt.axes()
ax.set_facecolor('blue')
plt.imshow(H, interpolation='nearest', origin='lower', extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]])
plt.xlabel('Phi')
plt.ylabel('Psi')
# plt.ylim(-5, 5)
plt.xlim(-3, 3)
plt.title("Free Energy Surface 300K_replica", fontsize=15)
plt.colorbar()
plt.savefig("Free_ene_surface_300K.png", dpi=500, bbox_inches='tight')
plt.show()
# Out:
# /state/partition1/job-25976548/ipykernel_3222941/2683569514.py:2: RuntimeWarning: divide by zero encountered in log
#   H = - np.log(H.T)
