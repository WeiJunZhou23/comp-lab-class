# %%
# pip install panda

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('Data/1hz3_T310.run.25000000.energy.xvg', skiprows=29, sep='\s+')
df.columns = ['Time', 'Potential', 'Kinetic Energy', 'Total Energy', 'Temperature', 'Pressure', 'Volume']
df
# Out:
#         Time      Potential  Kinetic Energy   Total Energy  Temperature  \
# 0      100.0 -175387.062500    35737.015625 -139650.046875   315.219452
# 1      200.0 -175059.531250    35401.789062 -139657.750000   312.262573
# 2      300.0 -175760.984375    35717.289062 -140043.687500   315.045502
# 3      400.0 -174898.718750    35252.562500 -139646.156250   310.946320
# 4      500.0 -176554.984375    35242.996094 -141311.984375   310.861969
# ..       ...            ...             ...            ...          ...
# 495  49600.0 -176148.750000    35003.425781 -141145.328125   308.748810
# 496  49700.0 -175596.437500    35622.363281 -139974.078125   314.208221
# 497  49800.0 -175233.296875    35012.890625 -140220.406250   308.832306
# 498  49900.0 -175552.906250    35534.488281 -140018.421875   313.433105
# 499  50000.0 -175183.906250    34867.031250 -140316.875000   307.545776
#
#        Pressure      Volume
# 0    116.084549  137.819077
# 1    -85.727356  137.437531
# 2    269.017548  135.811859
# 3   -129.284088  137.846680
# 4    289.023499  137.077408
# ..          ...         ...
# 495  123.643768  136.727814
# 496   76.174149  137.710068
# 497   25.778091  138.378967
# 498 -133.103729  138.065186
# 499 -132.031494  138.603043
#
# [500 rows x 7 columns]

# %%
df['Time']
# Out:
# 0        100.0
# 1        200.0
# 2        300.0
# 3        400.0
# 4        500.0
#         ...
# 495    49600.0
# 496    49700.0
# 497    49800.0
# 498    49900.0
# 499    50000.0
# Name: Time, Length: 500, dtype: float64

# %%
x_val = list(df['Time']/1000)
y_titles = ['Potential', 'Kinetic Energy', 'Total Energy', 'Temperature', 'Pressure', 'Volume']
y_labels = ['Potential, kJ/mol', 'Kinetic Energy, kJ/mol', 'Total Energy, kJ/mol', 'Temperature, K', 
            'Pressure, bar', 'Volume, nm^3']

i=0

for y_title in y_titles:
    y_val = list(df[y_title])
    plt.plot(x_val, y_val, color='black')
    plt.xlabel("Time, ns", fontsize=10)
    plt.ylabel("%s" % y_labels[i], fontsize=10)
    plt.xlim(0, 50)
    plt.title("Time vs %s" % y_title, fontsize=15)
    plt.show()
    i += 1

# %%
x_val = list(df['Time']/1000)
y_val_potential = list(df['Potential'])
y_val_temp = list(df['Temperature'])

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

ax1.set_xlabel("Time, ns", fontsize=10)
ax1.set_ylabel("Potential, kJ/mol", fontsize=10)
ax2.set_ylabel("Temperature, K", fontsize=10)
ax1.plot(x_val, y_val_potential, color='yellow', label='Potential')
ax2.plot(x_val, y_val_temp, color='green', label='Temperature')
plt.xlim(0, 50)
plt.title("Time vs Potential & Temperature")
ax1.legend(loc='upper right')
ax2.legend(loc='lower right')
plt.show()
